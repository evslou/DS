# %% [markdown]
# <center><img src="https://github.com/hse-ds/iad-applied-ds/blob/master/2021/hw/hw1/img/logo_hse.png?raw=1" width="1000"></center>
#
# <h1><center>Прикладные задачи анализа данных</center></h1>
# <h2><center>Домашнее задание 3: прогнозирование временных рядов</center></h2>

# %% [markdown]
# **Мягкий дедлайн:** 23:59MSK 19.05.2024
#
# **Жесткий дедлайн:** 23:59MSK 26.05.2024

# %%
# !pip install -r requirements.txt

# %%
import warnings
import gdown
import pandas as pd
import numpy as np
from copy import deepcopy

warnings.filterwarnings("ignore")

# %% [markdown]
# В данной задаче мы будем решать одну из актуальных практических задач, с которыми, в том числе, сталкиваются разработчики ETNA - прогнозирование объема необходимой наличности в банкоматах. Пожалуй, ни для кого не секрет, что отсутствие необходимой суммы в банкомате не делает клиента банка счастливее. В то же время, избыток заправленной в банкомат наличности приводит к упущенной выгоде - ведь, в конечном счете, эти деньги могли быть размещены в качестве краткосрочного депозита на межбанковском рынке. Для кредитной организации с обширной сетью банкоматов даже незначительное улучшение качества предсказания способно внести значительный вклад в прибыльность этой ветки бизнеса.
#
# В качестве инструмента воспользуемся библиотекой ETNA, документацию можно прочитать [тут](https://docs.etna.ai/stable/), и [чат](https://t.me/etna_support) комьюнити.
#
# Мы будем использовать дневные данные реальных банкоматов для чего возьмем мультисегментный датасет.

# %%
url = 'https://gist.githubusercontent.com/Polzovat123/4d6d5e544e93429c2d3db29196e9c918/raw/24b27e60f587128d71678e267f51cd48472c6a84/atms_daily_cash.csv'
output = 'atms_daily_cash.csv'
gdown.download(url=url, output=output, quiet=False, fuzzy=True)

df = pd.read_csv('atms_daily_cash.csv', index_col=False)
# Out:
# Downloading...
# From: https://gist.githubusercontent.com/Polzovat123/4d6d5e544e93429c2d3db29196e9c918/raw/24b27e60f587128d71678e267f51cd48472c6a84/atms_daily_cash.csv
# To: /content/atms_daily_cash.csv
# 100%|██████████| 258k/258k [00:00<00:00, 4.98MB/s]

# %% [markdown]
# Полученные данные были просуммированы по банкоматам и дням эксплуатации, после чего залиты в gist, откуда мы и берем их.
#
# Взглянем на то, что представляют из себя данные после этих действий:

# %%
df.head()
# Out:
#      datetime  atm_id  operation_value
# 0  2017-08-16      74         2.059266
# 1  2017-08-17      74         1.029633
# 2  2017-08-18      74         0.686422
# 3  2017-08-19      74        33.301267
# 4  2017-08-20      74       -12.237921

# %%
df[abs(df.operation_value) < 0.01]
# Out:
#         datetime  atm_id  operation_value
# 1273  2017-06-21      87     2.220446e-16

# %% [markdown]
# ### Задание 1. EDA (1.75 балл)
#
# Проведите разведывательный анализ данных с помощью `ETNA`- постройте графики, на которых можно судить о наличии тренда, сезонности и прочих зависимостей. Проанализируйте корреляции. Какие выводы вы можете сделать?
#
# Ссылку на туториал по EDA можно найти [тут](https://docs.etna.ai/stable/tutorials/103-EDA.html#EDA).

# %%
df.atm_id.unique()
# Out:
# array([ 74,  85,  86,  87,  88,  90,  91,  93,  94,  96,  97,  98,  99,
#        100, 101, 102, 103, 104, 105, 106])

# %%
from etna.datasets import TSDataset

# %%
ts = TSDataset(df.rename(columns={'datetime': 'timestamp', 'atm_id': 'segment', 'operation_value': 'target'}), freq="D")
ts.head(120)
# Out:
# segment            100          101         102         103          104  \
# feature         target       target      target      target       target
# timestamp
# 2017-06-09         NaN          NaN         NaN         NaN          NaN
# 2017-06-10         NaN          NaN         NaN         NaN          NaN
# 2017-06-11         NaN          NaN         NaN         NaN          NaN
# 2017-06-12         NaN          NaN         NaN         NaN          NaN
# 2017-06-13         NaN          NaN         NaN         NaN          NaN
# ...                ...          ...         ...         ...          ...
# 2017-10-02  130.557440    44.656646  420.796221  -77.281297   -30.182950
# 2017-10-03  243.405196    12.502684  141.383294  -16.032854    19.268843
# 2017-10-04  -62.366330  1549.732747  288.091260   80.576122    63.631308
# 2017-10-05   95.402834    25.064204  119.672751   62.101568  1800.914824
# 2017-10-06  263.703672   128.615847  168.712691  173.890273   183.804166
#
# segment            105         106          74          85          86  \
# feature         target      target      target      target      target
# timestamp
# 2017-06-09         NaN         NaN         NaN         NaN         NaN
# 2017-06-10         NaN         NaN         NaN         NaN         NaN
# 2017-06-11         NaN         NaN         NaN         NaN         NaN
# 2017-06-12         NaN         NaN         NaN         NaN         NaN
# 2017-06-13         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2017-10-02   66.308353   34.948679  510.315439  212.722139    7.707537
# 2017-10-03  116.701525  131.086966  529.201847  197.836590    3.383079
# 2017-10-04 -258.467254   59.336268   -1.147305  207.662229   82.753060
# 2017-10-05  147.325746   19.268843  480.573760  493.488297   55.335409
# 2017-10-06  137.264763  -14.679622  383.170496         NaN  116.289671
#
# segment             87          88          90          91          93  \
# feature         target      target      target      target      target
# timestamp
# 2017-06-09    0.617780         NaN         NaN         NaN         NaN
# 2017-06-10    1.441486         NaN         NaN         NaN         NaN
# 2017-06-11   -0.235345         NaN         NaN         NaN         NaN
# 2017-06-12  -13.532317         NaN         NaN         NaN         NaN
# 2017-06-13    7.398647         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2017-10-02  379.022547 -284.149238 -114.465750  622.545416   62.484003
# 2017-10-03   70.162122   76.016320  137.706034  115.201202  205.897144
# 2017-10-04 -211.162980  137.735452  159.063560 -161.211080  332.953833
# 2017-10-05 -308.036719  127.233197  271.940734   66.249517  147.649345
# 2017-10-06  603.011810 -105.816835 -349.457376   77.869659   62.748765
#
# segment              94          96          97           98          99
# feature          target      target      target       target      target
# timestamp
# 2017-06-09          NaN         NaN         NaN          NaN         NaN
# 2017-06-10          NaN         NaN         NaN          NaN         NaN
# 2017-06-11          NaN         NaN         NaN          NaN         NaN
# 2017-06-12          NaN         NaN         NaN          NaN         NaN
# 2017-06-13          NaN         NaN         NaN          NaN         NaN
# ...                 ...         ...         ...          ...         ...
# 2017-10-02   191.246940  155.239210   50.599098    -3.088898  -99.521366
# 2017-10-03    96.844320   -8.796006   49.863646  1997.144778   -0.941379
# 2017-10-04  -214.281297  -57.924200  201.101997    16.209362  -96.991411
# 2017-10-05    11.649560   92.049173  340.837878    23.946317  164.564741
# 2017-10-06  1624.574490   39.567318 -245.640971   111.700451   52.746618
#
# [120 rows x 20 columns]

# %%
from etna.transforms import TimeSeriesImputerTransform

# %%
ts1 = TSDataset(df.rename(columns={'datetime': 'timestamp', 'atm_id': 'segment', 'operation_value': 'target'}), freq="D")
transforms = [TimeSeriesImputerTransform(in_column='target', strategy='constant', constant_value=0).fit(ts1)]
ts1.transform(transforms)

# %%
transforms
# Out:
# [TimeSeriesImputerTransform(in_column = 'target', strategy = 'constant', window = -1, seasonality = 1, default_value = None, constant_value = 0, )]

# %%
ts1.head(120)
# Out:
# segment            100          101         102         103          104  \
# feature         target       target      target      target       target
# timestamp
# 2017-06-09         NaN          NaN         NaN         NaN          NaN
# 2017-06-10         NaN          NaN         NaN         NaN          NaN
# 2017-06-11         NaN          NaN         NaN         NaN          NaN
# 2017-06-12         NaN          NaN         NaN         NaN          NaN
# 2017-06-13         NaN          NaN         NaN         NaN          NaN
# ...                ...          ...         ...         ...          ...
# 2017-10-02  130.557440    44.656646  420.796221  -77.281297   -30.182950
# 2017-10-03  243.405196    12.502684  141.383294  -16.032854    19.268843
# 2017-10-04  -62.366330  1549.732747  288.091260   80.576122    63.631308
# 2017-10-05   95.402834    25.064204  119.672751   62.101568  1800.914824
# 2017-10-06  263.703672   128.615847  168.712691  173.890273   183.804166
#
# segment            105         106          74          85          86  \
# feature         target      target      target      target      target
# timestamp
# 2017-06-09         NaN         NaN         NaN         NaN         NaN
# 2017-06-10         NaN         NaN         NaN         NaN         NaN
# 2017-06-11         NaN         NaN         NaN         NaN         NaN
# 2017-06-12         NaN         NaN         NaN         NaN         NaN
# 2017-06-13         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2017-10-02   66.308353   34.948679  510.315439  212.722139    7.707537
# 2017-10-03  116.701525  131.086966  529.201847  197.836590    3.383079
# 2017-10-04 -258.467254   59.336268   -1.147305  207.662229   82.753060
# 2017-10-05  147.325746   19.268843  480.573760  493.488297   55.335409
# 2017-10-06  137.264763  -14.679622  383.170496    0.000000  116.289671
#
# segment             87          88          90          91          93  \
# feature         target      target      target      target      target
# timestamp
# 2017-06-09    0.617780         NaN         NaN         NaN         NaN
# 2017-06-10    1.441486         NaN         NaN         NaN         NaN
# 2017-06-11   -0.235345         NaN         NaN         NaN         NaN
# 2017-06-12  -13.532317         NaN         NaN         NaN         NaN
# 2017-06-13    7.398647         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2017-10-02  379.022547 -284.149238 -114.465750  622.545416   62.484003
# 2017-10-03   70.162122   76.016320  137.706034  115.201202  205.897144
# 2017-10-04 -211.162980  137.735452  159.063560 -161.211080  332.953833
# 2017-10-05 -308.036719  127.233197  271.940734   66.249517  147.649345
# 2017-10-06  603.011810 -105.816835 -349.457376   77.869659   62.748765
#
# segment              94          96          97           98          99
# feature          target      target      target       target      target
# timestamp
# 2017-06-09          NaN         NaN         NaN          NaN         NaN
# 2017-06-10          NaN         NaN         NaN          NaN         NaN
# 2017-06-11          NaN         NaN         NaN          NaN         NaN
# 2017-06-12          NaN         NaN         NaN          NaN         NaN
# 2017-06-13          NaN         NaN         NaN          NaN         NaN
# ...                 ...         ...         ...          ...         ...
# 2017-10-02   191.246940  155.239210   50.599098    -3.088898  -99.521366
# 2017-10-03    96.844320   -8.796006   49.863646  1997.144778   -0.941379
# 2017-10-04  -214.281297  -57.924200  201.101997    16.209362  -96.991411
# 2017-10-05    11.649560   92.049173  340.837878    23.946317  164.564741
# 2017-10-06  1624.574490   39.567318 -245.640971   111.700451   52.746618
#
# [120 rows x 20 columns]

# %%
ts.isnull().sum() - ts1.isnull().sum()
# Out:
# segment  feature
# 100      target     3
# 101      target     3
# 102      target     3
# 103      target     3
# 104      target     3
# 105      target     3
# 106      target     3
# 74       target     3
# 85       target     3
# 86       target     3
# 87       target     3
# 88       target     3
# 90       target     3
# 91       target     3
# 93       target     3
# 94       target     3
# 96       target     3
# 97       target     3
# 98       target     3
# 99       target     3
# dtype: int64

# %% [markdown]
# интересное наблюдение - это значит, что TimeSeriesImputerTransform, заполняющий пропуски внутри данных, для каждого сегмента заполнил по 3 значения ровно. Это можно исследовать во втором задании.

# %%
ts1.plot()

# %%
from etna.analysis import plot_periodogram
plot_periodogram(ts1, period=365.2425, amplitude_aggregation_mode="per-segment", xticks=[1, 2, 4, 6, 12, 26, 52, 104])

# %%
from etna.analysis import stl_plot
stl_plot(ts=ts1, period=52)

# %%
from etna.analysis import seasonal_plot
seasonal_plot(ts=ts1, cycle="quarter")

# %% [markdown]
# ### Задание 2. Работа с пропущенными значениями и выбросами (1 балл)
#
# Проанализируйте, есть ли в данных пропущенные значения, и подберите оптимальный метод их заполнения средствами ETNA. Какие методы вы выберете и почему? Совет: возможно, лучше сохранить заполненные данные в отдельный объект, поскольку некоторые модели заполняют пропуски встроенными методами, и подача на вход "сырых" данных (на языке временных рядов это данные с нерегулярными интервалами) может принести лучший результат.
#
# Импорты всех необходимых компонент произведите самостоятельно.

# %%
from etna.transforms import TimeSeriesImputerTransform

# %%
ts2 = TSDataset(df.rename(columns={'datetime': 'timestamp', 'atm_id': 'segment', 'operation_value': 'target'}), freq="D")
transforms = [TimeSeriesImputerTransform(in_column='target', strategy='constant', constant_value=0).fit(ts2)]
ts2.transform(transforms)

# %%
ts2.df.fillna(0, inplace=True)

# %%
segments = self.segments
k = min(n_segments, len(segments))
columns_num = min(2, k)
rows_num = math.ceil(k / columns_num)
start = self.df.index.min() if start is None else pd.Timestamp(start)
end = self.df.index.max() if end is None else pd.Timestamp(end)

figsize = (figsize[0] * columns_num, figsize[1] * rows_num)
_, ax = plt.subplots(rows_num, columns_num, figsize=figsize, squeeze=False)
ax = ax.ravel()
rnd_state = np.random.RandomState(seed)
for i, segment in enumerate(sorted(rnd_state.choice(segments, size=k, replace=False))):
    df_slice = self[start:end, segment, column]  # type: ignore
    ax[i].plot(df_slice.index, df_slice.values)
    ax[i].set_title(segment)
    ax[i].grid()

# %%
from etna.transforms import (
    LinearTrendTransform,
    DensityOutliersTransform,
    TimeSeriesImputerTransform,
)

transforms = [
    # удаляем выбросы из данных
    DensityOutliersTransform(
        in_column="target",
        window_size=45,
        n_neighbors=25,
        distance_coef=1.9
    ),
    # заполняем образовавшиеся пропуски
    TimeSeriesImputerTransform(
        in_column="target",
        strategy="running_mean"
    ),
    # вычитаем тренд
    LinearTrendTransform(in_column="target"),
]

# %% [markdown]
# Проверьте ряды на наличие выбросов, и очистите их соответствующим образом. Обоснуйте выбор.

# %%
#YOUR CODE HERE#

# %% [markdown]
# ### Задание 3. Построение Prophet (1.25 балла)
#
# Постройте прогнозы с помощью Prophet и `etna.Pipeline`, под капотом `etna.Pipeline` обучит `ProphetModel` для каждого сегмента в отдельности. После этого оцените качество по SMAPE на кросс-валидации. В качестве горизонта предсказания возьмите 5 дней - этого же горизонта будем придерживаться и в дальнейшем.
#
# Отрисуйте получившийся прогноз.

# %%
from etna.pipeline import Pipeline
from etna.models import ProphetModel
from etna.metrics import SMAPE, MAE
from etna.analysis import plot_backtest

# %%
HORIZON = 5

# %%
model = ProphetModel(daily_seasonality=True, yearly_seasonality=True)

# Создаем пайплайн с горизонтом предсказания 5 дней
pipeline = Pipeline(model=model, horizon=HORIZON)

# Оценка качества модели с помощью кросс-валидации
metrics = [SMAPE(), MAE()]

n_folds = 70  # количество фолдов для кросс-валидации

metrics_df, forecast_df, fold_info_df = pipeline.backtest(ts1, metrics=metrics, n_folds=n_folds, n_jobs=2)
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/fjchxne9.json
# 22:27:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/ovvku2p9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/bqyfnfoi.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4321', 'data', 'file=/tmp/tmp7wap27b7/fjchxne9.json', 'init=/tmp/tmp7wap27b7/ovvku2p9.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model025oe9tx/prophet_model-20240518222702.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/zb97cwo5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67252', 'data', 'file=/tmp/tmp7wap27b7/bqyfnfoi.json', 'init=/tmp/tmp7wap27b7/zb97cwo5.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model7w_pxdw7/prophet_model-20240518222703.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/a8zs7w06.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/_qi75121.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25047', 'data', 'file=/tmp/tmp7wap27b7/a8zs7w06.json', 'init=/tmp/tmp7wap27b7/_qi75121.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model8v8hx55j/prophet_model-20240518222703.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/f_ocarns.json
# 22:27:03 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/6xsfl836.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=513', 'data', 'file=/tmp/tmp7wap27b7/f_ocarns.json', 'init=/tmp/tmp7wap27b7/6xsfl836.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model7rfdqcqf/prophet_model-20240518222703.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:03 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/g0scuggj.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/u70n4oyc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92246', 'data', 'file=/tmp/tmp7wap27b7/g0scuggj.json', 'init=/tmp/tmp7wap27b7/u70n4oyc.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model5hnzkdwi/prophet_model-20240518222703.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/7hv9uya5.json
# 22:27:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/42vwsfts.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52853', 'data', 'file=/tmp/tmp7wap27b7/7hv9uya5.json', 'init=/tmp/tmp7wap27b7/42vwsfts.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modeljbv6t4jv/prophet_model-20240518222703.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/4ug39h0o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/79wj7luz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/igrthpp4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33928', 'data', 'file=/tmp/tmp7wap27b7/4ug39h0o.json', 'init=/tmp/tmp7wap27b7/igrthpp4.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model4iyaly4z/prophet_model-20240518222704.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/eqdp955x.json
# 22:27:04 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23996', 'data', 'file=/tmp/tmp7wap27b7/79wj7luz.json', 'init=/tmp/tmp7wap27b7/eqdp955x.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model2r3yg56z/prophet_model-20240518222704.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/tnt7_bgj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/7f7oybu9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69534', 'data', 'file=/tmp/tmp7wap27b7/tnt7_bgj.json', 'init=/tmp/tmp7wap27b7/7f7oybu9.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelqp2pxvuo/prophet_model-20240518222704.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/ugpbrr8x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/051kuq54.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/d53cwko5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88161', 'data', 'file=/tmp/tmp7wap27b7/ugpbrr8x.json', 'init=/tmp/tmp7wap27b7/d53cwko5.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelv_rinaat/prophet_model-20240518222704.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/xtqem0g0.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16035', 'data', 'file=/tmp/tmp7wap27b7/051kuq54.json', 'init=/tmp/tmp7wap27b7/xtqem0g0.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelwymlg_tr/prophet_model-20240518222705.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:idx 0
# 22:27:05 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/it90lczh.json
# 22:27:05 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/77x9b1og.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61700', 'data', 'file=/tmp/tmp7wap27b7/it90lczh.json', 'init=/tmp/tmp7wap27b7/77x9b1og.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modellb0agcud/prophet_model-20240518222705.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/y9pps3cm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/6tlp422b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/pe7osofj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39844', 'data', 'file=/tmp/tmp7wap27b7/y9pps3cm.json', 'init=/tmp/tmp7wap27b7/pe7osofj.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelycms_s2t/prophet_model-20240518222705.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/0mlanob8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/1yzj67se.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83611', 'data', 'file=/tmp/tmp7wap27b7/6tlp422b.json', 'init=/tmp/tmp7wap27b7/1yzj67se.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelakvqckcs/prophet_model-20240518222705.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/e2rglwwi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51158', 'data', 'file=/tmp/tmp7wap27b7/0mlanob8.json', 'init=/tmp/tmp7wap27b7/e2rglwwi.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelc4mf4823/prophet_model-20240518222705.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/cuiwvu6r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/q8mtbztl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/7w9zujmq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/4e03g_bz.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5072', 'data', 'file=/tmp/tmp7wap27b7/cuiwvu6r.json', 'init=/tmp/tmp7wap27b7/7w9zujmq.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelwajkpggq/prophet_model-20240518222706.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78950', 'data', 'file=/tmp/tmp7wap27b7/q8mtbztl.json', 'init=/tmp/tmp7wap27b7/4e03g_bz.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model66yctdch/prophet_model-20240518222706.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:06 - cmdstanpy - INFO - Chain [1] start processing
# 22:27:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/a7rggog1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/l0bozzya.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/bis9pvwr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99927', 'data', 'file=/tmp/tmp7wap27b7/a7rggog1.json', 'init=/tmp/tmp7wap27b7/bis9pvwr.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelda46zev_/prophet_model-20240518222706.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:  3.4min
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/ktpgy3xv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42487', 'data', 'file=/tmp/tmp7wap27b7/l0bozzya.json', 'init=/tmp/tmp7wap27b7/ktpgy3xv.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model6821j190/prophet_model-20240518222706.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/mw6q9_fo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/whqa4d2g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/6ws0yhzf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67096', 'data', 'file=/tmp/tmp7wap27b7/whqa4d2g.json', 'init=/tmp/tmp7wap27b7/6ws0yhzf.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modeluvk2igeb/prophet_model-20240518222707.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/myypfvgi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/mpkj7e04.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24523', 'data', 'file=/tmp/tmp7wap27b7/myypfvgi.json', 'init=/tmp/tmp7wap27b7/mpkj7e04.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelo8jns5c8/prophet_model-20240518222707.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/ev_l_vov.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=133', 'data', 'file=/tmp/tmp7wap27b7/mw6q9_fo.json', 'init=/tmp/tmp7wap27b7/ev_l_vov.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelc75iofsv/prophet_model-20240518222707.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/2j7dbs3r.json
# 22:27:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/cayxyygj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58602', 'data', 'file=/tmp/tmp7wap27b7/2j7dbs3r.json', 'init=/tmp/tmp7wap27b7/cayxyygj.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modeln7v2f9xb/prophet_model-20240518222707.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/mcgiqtnl.json
# 22:27:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/d7jxqwmg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86050', 'data', 'file=/tmp/tmp7wap27b7/mcgiqtnl.json', 'init=/tmp/tmp7wap27b7/d7jxqwmg.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelgauvx4e3/prophet_model-20240518222708.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/i4fqfy88.json
# 22:27:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/mvhcot8n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20986', 'data', 'file=/tmp/tmp7wap27b7/i4fqfy88.json', 'init=/tmp/tmp7wap27b7/mvhcot8n.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modeldci30lnk/prophet_model-20240518222708.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/tg1l04f6.json
# 22:27:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/1zazyv1i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57845', 'data', 'file=/tmp/tmp7wap27b7/tg1l04f6.json', 'init=/tmp/tmp7wap27b7/1zazyv1i.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelv5fy_eiw/prophet_model-20240518222708.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/8lnqrevb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/1jdwpujz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24030', 'data', 'file=/tmp/tmp7wap27b7/8lnqrevb.json', 'init=/tmp/tmp7wap27b7/1jdwpujz.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelw1t_6qx8/prophet_model-20240518222708.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/6rev90v_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/rixpzw8n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/3ariz8yq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/eioergmx.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1050', 'data', 'file=/tmp/tmp7wap27b7/6rev90v_.json', 'init=/tmp/tmp7wap27b7/eioergmx.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model46ljq64w/prophet_model-20240518222709.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:09 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56025', 'data', 'file=/tmp/tmp7wap27b7/rixpzw8n.json', 'init=/tmp/tmp7wap27b7/3ariz8yq.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelkc5fv4fa/prophet_model-20240518222709.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/c8xxc2v5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/rmc8upgr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/sscm8e7u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/8a0b8ni6.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27470', 'data', 'file=/tmp/tmp7wap27b7/c8xxc2v5.json', 'init=/tmp/tmp7wap27b7/sscm8e7u.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_models1ddxky5/prophet_model-20240518222709.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44702', 'data', 'file=/tmp/tmp7wap27b7/rmc8upgr.json', 'init=/tmp/tmp7wap27b7/8a0b8ni6.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model04rus7ha/prophet_model-20240518222709.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:09 - cmdstanpy - INFO - Chain [1] done processing
# 22:27:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/693xw16b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/9_p2ah84.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/oe9bhhb1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47027', 'data', 'file=/tmp/tmp7wap27b7/693xw16b.json', 'init=/tmp/tmp7wap27b7/oe9bhhb1.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model869saen0/prophet_model-20240518222710.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:10 - cmdstanpy - INFO - Chain [1] start processing
# 22:27:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/vrz05a9t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/p0oo12mg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40460', 'data', 'file=/tmp/tmp7wap27b7/vrz05a9t.json', 'init=/tmp/tmp7wap27b7/p0oo12mg.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelhimc5y5t/prophet_model-20240518222710.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:10 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/5693lpfv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/cb6fhb2o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/a50qw_h7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48494', 'data', 'file=/tmp/tmp7wap27b7/5693lpfv.json', 'init=/tmp/tmp7wap27b7/cb6fhb2o.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelnkczx5e0/prophet_model-20240518222711.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# 22:27:11 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28470', 'data', 'file=/tmp/tmp7wap27b7/9_p2ah84.json', 'init=/tmp/tmp7wap27b7/a50qw_h7.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelqo6we3_n/prophet_model-20240518222711.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:  3.5min
# 22:27:11 - cmdstanpy - INFO - Chain [1] done processing
# 22:27:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/dse416q6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/ct_krmi0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/avznv5pr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/8u5czn84.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44873', 'data', 'file=/tmp/tmp7wap27b7/dse416q6.json', 'init=/tmp/tmp7wap27b7/avznv5pr.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelmqq7nd_w/prophet_model-20240518222711.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73985', 'data', 'file=/tmp/tmp7wap27b7/ct_krmi0.json', 'init=/tmp/tmp7wap27b7/8u5czn84.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modeltvcm0vbh/prophet_model-20240518222711.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:11 - cmdstanpy - INFO - Chain [1] start processing
# 22:27:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:11 - cmdstanpy - INFO - Chain [1] done processing
# 22:27:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/2ur5z3t2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/pmt17uuk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/nkdfms5r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/tv4qajk2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43187', 'data', 'file=/tmp/tmp7wap27b7/pmt17uuk.json', 'init=/tmp/tmp7wap27b7/tv4qajk2.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelp23s5_6g/prophet_model-20240518222711.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93184', 'data', 'file=/tmp/tmp7wap27b7/2ur5z3t2.json', 'init=/tmp/tmp7wap27b7/nkdfms5r.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model_iz4ckoq/prophet_model-20240518222711.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:11 - cmdstanpy - INFO - Chain [1] start processing
# 22:27:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/8tl8h4l1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/nfzwx7q3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/_idh_fs0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86514', 'data', 'file=/tmp/tmp7wap27b7/nfzwx7q3.json', 'init=/tmp/tmp7wap27b7/_idh_fs0.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelw4pyk1h6/prophet_model-20240518222712.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/sv4w4g88.json
# 22:27:12 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72960', 'data', 'file=/tmp/tmp7wap27b7/8tl8h4l1.json', 'init=/tmp/tmp7wap27b7/sv4w4g88.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model2a18gd51/prophet_model-20240518222712.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/tmkysfnm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/gezgxwd1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/eujxb5ml.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/tz737zqu.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91101', 'data', 'file=/tmp/tmp7wap27b7/tmkysfnm.json', 'init=/tmp/tmp7wap27b7/eujxb5ml.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modeli1njvmxf/prophet_model-20240518222712.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# 22:27:12 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60596', 'data', 'file=/tmp/tmp7wap27b7/gezgxwd1.json', 'init=/tmp/tmp7wap27b7/tz737zqu.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelgt3_qofi/prophet_model-20240518222712.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/cewdlflh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/axfv6sqm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/4oajinjb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/kexz9jcv.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93747', 'data', 'file=/tmp/tmp7wap27b7/cewdlflh.json', 'init=/tmp/tmp7wap27b7/4oajinjb.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelwtv08q6t/prophet_model-20240518222712.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:12 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3400', 'data', 'file=/tmp/tmp7wap27b7/axfv6sqm.json', 'init=/tmp/tmp7wap27b7/kexz9jcv.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelk_zphij9/prophet_model-20240518222712.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:12 - cmdstanpy - INFO - Chain [1] done processing
# 22:27:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/dycpaeo6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/mn6gh620.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/dephgjl9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38062', 'data', 'file=/tmp/tmp7wap27b7/dycpaeo6.json', 'init=/tmp/tmp7wap27b7/dephgjl9.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modeleunazlv6/prophet_model-20240518222713.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/6x3eyfz_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11693', 'data', 'file=/tmp/tmp7wap27b7/mn6gh620.json', 'init=/tmp/tmp7wap27b7/6x3eyfz_.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modeloquwb1_y/prophet_model-20240518222713.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/9amm_ube.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/igl4a5km.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/0s1og_e5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82653', 'data', 'file=/tmp/tmp7wap27b7/9amm_ube.json', 'init=/tmp/tmp7wap27b7/0s1og_e5.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model7nfca8k6/prophet_model-20240518222713.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/v9uknvw4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23989', 'data', 'file=/tmp/tmp7wap27b7/igl4a5km.json', 'init=/tmp/tmp7wap27b7/v9uknvw4.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model718k7gc3/prophet_model-20240518222713.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 22:27:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/nh5th518.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/4g0pgqyg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80560', 'data', 'file=/tmp/tmp7wap27b7/nh5th518.json', 'init=/tmp/tmp7wap27b7/4g0pgqyg.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelsdyw9zkv/prophet_model-20240518222714.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/e1jde9hk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/q_9jnqnn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67062', 'data', 'file=/tmp/tmp7wap27b7/e1jde9hk.json', 'init=/tmp/tmp7wap27b7/q_9jnqnn.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelk3otvd4q/prophet_model-20240518222714.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/p3znyppg.json
# 22:27:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/kgho_efp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74696', 'data', 'file=/tmp/tmp7wap27b7/p3znyppg.json', 'init=/tmp/tmp7wap27b7/kgho_efp.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelcvvrtfq7/prophet_model-20240518222714.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/y035t3fa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/zqpsgev7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/uw4czals.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64510', 'data', 'file=/tmp/tmp7wap27b7/y035t3fa.json', 'init=/tmp/tmp7wap27b7/uw4czals.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelaz72kq5m/prophet_model-20240518222715.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/_7pgp3h5.json
# 22:27:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28517', 'data', 'file=/tmp/tmp7wap27b7/zqpsgev7.json', 'init=/tmp/tmp7wap27b7/_7pgp3h5.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelfhjhrk8w/prophet_model-20240518222715.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/q4s958b8.json
# 22:27:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/3c2_yq7f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/1p2mddn0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6845', 'data', 'file=/tmp/tmp7wap27b7/q4s958b8.json', 'init=/tmp/tmp7wap27b7/1p2mddn0.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modeliiweipag/prophet_model-20240518222715.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/xoc36ggk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92295', 'data', 'file=/tmp/tmp7wap27b7/3c2_yq7f.json', 'init=/tmp/tmp7wap27b7/xoc36ggk.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelnstbsrlx/prophet_model-20240518222715.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/nqp51buz.json
# 22:27:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/sxl9t17v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13100', 'data', 'file=/tmp/tmp7wap27b7/nqp51buz.json', 'init=/tmp/tmp7wap27b7/sxl9t17v.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelrmwxqtvw/prophet_model-20240518222716.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/aduy3c6d.json
# 22:27:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:  3.6min
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/5j7jnut7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46628', 'data', 'file=/tmp/tmp7wap27b7/aduy3c6d.json', 'init=/tmp/tmp7wap27b7/5j7jnut7.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelzpybop_6/prophet_model-20240518222716.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:16 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/snz30eu_.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/dzzh_n2c.json
# 22:27:16 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79431', 'data', 'file=/tmp/tmp7wap27b7/snz30eu_.json', 'init=/tmp/tmp7wap27b7/dzzh_n2c.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelhyivwivx/prophet_model-20240518222716.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/3hh6v5zp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/m5pbcn1b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14270', 'data', 'file=/tmp/tmp7wap27b7/3hh6v5zp.json', 'init=/tmp/tmp7wap27b7/m5pbcn1b.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelupqsoyt6/prophet_model-20240518222716.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/euco_hw1.json
# 22:27:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/yqjmtf91.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25114', 'data', 'file=/tmp/tmp7wap27b7/euco_hw1.json', 'init=/tmp/tmp7wap27b7/yqjmtf91.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model0p80d6gc/prophet_model-20240518222716.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/e9qdny2p.json
# 22:27:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/9uzd4n2m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39299', 'data', 'file=/tmp/tmp7wap27b7/e9qdny2p.json', 'init=/tmp/tmp7wap27b7/9uzd4n2m.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelxxyw46ld/prophet_model-20240518222717.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:27:17 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/fzmwjxhy.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/5b_9wm15.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7363', 'data', 'file=/tmp/tmp7wap27b7/fzmwjxhy.json', 'init=/tmp/tmp7wap27b7/5b_9wm15.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modellcyv_gzi/prophet_model-20240518222717.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:27:17 - cmdstanpy - INFO - Chain [1] start processing
# ...
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33895', 'data', 'file=/tmp/tmp7wap27b7/h3okke8d.json', 'init=/tmp/tmp7wap27b7/m9z0xxii.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modeluss0z0e5/prophet_model-20240518222915.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:29:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/fgz37ela.json
# 22:29:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/la9pewte.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61034', 'data', 'file=/tmp/tmp7wap27b7/fgz37ela.json', 'init=/tmp/tmp7wap27b7/la9pewte.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modeleont6qpd/prophet_model-20240518222915.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:29:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/zj8_xgrt.json
# 22:29:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/4ua68i41.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55538', 'data', 'file=/tmp/tmp7wap27b7/zj8_xgrt.json', 'init=/tmp/tmp7wap27b7/4ua68i41.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model66ji8byt/prophet_model-20240518222916.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:29:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/4pe36v4v.json
# 22:29:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/r8ln6r2o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78901', 'data', 'file=/tmp/tmp7wap27b7/4pe36v4v.json', 'init=/tmp/tmp7wap27b7/r8ln6r2o.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelish7tu7o/prophet_model-20240518222916.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:29:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:29:16 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/ywu0z5ga.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/44mxcx7f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64186', 'data', 'file=/tmp/tmp7wap27b7/ywu0z5ga.json', 'init=/tmp/tmp7wap27b7/44mxcx7f.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model6tmwcs7a/prophet_model-20240518222916.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:29:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/kg0hhaft.json
# 22:29:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/f5hrw5t_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17535', 'data', 'file=/tmp/tmp7wap27b7/kg0hhaft.json', 'init=/tmp/tmp7wap27b7/f5hrw5t_.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model78hwrqwf/prophet_model-20240518222916.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:29:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:29:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/x7vw03up.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/kshs7b_n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84298', 'data', 'file=/tmp/tmp7wap27b7/x7vw03up.json', 'init=/tmp/tmp7wap27b7/kshs7b_n.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelii0qdsap/prophet_model-20240518222917.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:29:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:29:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/ndr5sdtu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/wd28t67t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83892', 'data', 'file=/tmp/tmp7wap27b7/ndr5sdtu.json', 'init=/tmp/tmp7wap27b7/wd28t67t.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelzjor2goz/prophet_model-20240518222917.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:29:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:29:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/aijkh8gb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/x2_v0aox.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93570', 'data', 'file=/tmp/tmp7wap27b7/aijkh8gb.json', 'init=/tmp/tmp7wap27b7/x2_v0aox.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_model59brzi1e/prophet_model-20240518222918.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:29:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:29:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/mvkh3ksv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7wap27b7/s1zvdri1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85599', 'data', 'file=/tmp/tmp7wap27b7/mvkh3ksv.json', 'init=/tmp/tmp7wap27b7/s1zvdri1.json', 'output', 'file=/tmp/tmp7wap27b7/prophet_modelry6hgcv3/prophet_model-20240518222918.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:29:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:29:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# [Parallel(n_jobs=2)]: Done  70 out of  70 | elapsed:  5.7min finished
# [Parallel(n_jobs=2)]: Using backend MultiprocessingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:   38.0s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:   40.8s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:   45.9s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:   50.2s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:   54.9s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:   55.7s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=2)]: Done  48 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=2)]: Done  49 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=2)]: Done  50 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=2)]: Done  51 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=2)]: Done  52 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=2)]: Done  53 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=2)]: Done  54 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=2)]: Done  55 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=2)]: Done  56 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=2)]: Done  57 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=2)]: Done  58 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=2)]: Done  59 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=2)]: Done  60 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=2)]: Done  61 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=2)]: Done  62 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=2)]: Done  63 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=2)]: Done  64 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=2)]: Done  65 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=2)]: Done  66 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=2)]: Done  67 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=2)]: Done  70 out of  70 | elapsed:  2.1min finished
# [Parallel(n_jobs=2)]: Using backend MultiprocessingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=2)]: Done  12 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=2)]: Done  13 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=2)]: Done  15 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=2)]: Done  17 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=2)]: Done  19 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=2)]: Done  20 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=2)]: Done  22 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=2)]: Done  23 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=2)]: Done  24 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=2)]: Done  25 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=2)]: Done  26 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=2)]: Done  27 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=2)]: Done  29 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=2)]: Done  30 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=2)]: Done  31 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=2)]: Done  32 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=2)]: Done  33 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=2)]: Done  34 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=2)]: Done  35 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=2)]: Done  36 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=2)]: Done  38 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=2)]: Done  39 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=2)]: Done  40 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=2)]: Done  41 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=2)]: Done  42 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=2)]: Done  43 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=2)]: Done  44 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=2)]: Done  45 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=2)]: Done  47 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=2)]: Done  48 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=2)]: Done  49 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=2)]: Done  50 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=2)]: Done  51 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=2)]: Done  52 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=2)]: Done  53 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=2)]: Done  54 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=2)]: Done  55 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=2)]: Done  56 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=2)]: Done  57 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=2)]: Done  58 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=2)]: Done  59 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=2)]: Done  60 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=2)]: Done  61 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=2)]: Done  62 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=2)]: Done  63 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=2)]: Done  64 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=2)]: Done  65 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=2)]: Done  66 tasks      | elapsed:   36.1s
# [Parallel(n_jobs=2)]: Done  67 tasks      | elapsed:   36.8s
# [Parallel(n_jobs=2)]: Done  70 out of  70 | elapsed:   38.4s finished

# %%
fold_info_df
# Out:
#    train_start_time train_end_time test_start_time test_end_time  fold_number
# 0        2017-06-09     2017-10-15      2017-10-16    2017-10-20            0
# 1        2017-06-09     2017-10-20      2017-10-21    2017-10-25            1
# 2        2017-06-09     2017-10-25      2017-10-26    2017-10-30            2
# 3        2017-06-09     2017-10-30      2017-10-31    2017-11-04            3
# 4        2017-06-09     2017-11-04      2017-11-05    2017-11-09            4
# ..              ...            ...             ...           ...          ...
# 65       2017-06-09     2018-09-05      2018-09-06    2018-09-10           65
# 66       2017-06-09     2018-09-10      2018-09-11    2018-09-15           66
# 67       2017-06-09     2018-09-15      2018-09-16    2018-09-20           67
# 68       2017-06-09     2018-09-20      2018-09-21    2018-09-25           68
# 69       2017-06-09     2018-09-25      2018-09-26    2018-09-30           69
#
# [70 rows x 5 columns]

# %%
plot_backtest(forecast_df=forecast_df, ts=ts, history_len='all')

# %%
metrics_mean_segment = metrics_df.groupby('segment')[['SMAPE', 'MAE']].mean()
metrics_mean_segment.sort_values(by='SMAPE')
# Out:
#               SMAPE         MAE
# segment
# 85        44.124840  221.068660
# 93        44.360659  248.477567
# 104       47.055497  229.835072
# 86        49.445262  127.911593
# 90        51.786705  157.745957
# 87        55.924469  252.851808
# 94        57.627476  199.289426
# 74        59.823840  682.114737
# 88        62.030090  176.199364
# 103       64.276651  324.069005
# 98        79.121088  179.357168
# 102       80.045330  164.711736
# 101       83.592485  255.678333
# 100       85.031908  261.950413
# 105       85.110993  290.233446
# 106       88.711018   67.144152
# 91        89.839678  252.344579
# 97        89.911917  281.484570
# 96       114.745741  212.676437
# 99       123.727137  304.834701

# %%
metrics_mean_segment = metrics_df.groupby('segment')[['SMAPE', 'MAE']].mean()
metrics_mean_segment.sort_values(by='SMAPE')
# вывод после обучения на 70 фолдах
# Out:
#               SMAPE         MAE
# segment
# 93        85.607019  340.517841
# 103       86.931731  229.580228
# 85        87.529800  272.802464
# 74        88.036331  795.085313
# 94        88.903517  236.678758
# 104       97.492397  288.098822
# 90        98.201308  238.491277
# 98       100.961131  206.894211
# 87       101.037956  284.287048
# 86       108.103655  216.176430
# 105      109.109513  385.720933
# 88       112.524100  366.302184
# 96       114.955236  209.815419
# 102      116.894985  282.243028
# 97       119.760383  284.794203
# 91       120.901881  334.923241
# 101      124.366409  266.219353
# 106      124.553504   88.143945
# 100      124.861645  379.619744
# 99       126.660497  276.503464

# %% [markdown]
# Исходя из статистики по каждому ряду, какой можно сделать вывод о том, как лучше предсказывать итоговое значение? Посчитайте то же самое исходя из MAE.

# %%
#YOUR CODE HERE#

# %% [markdown]
# ### Задание 4. Иерархический временной ряд (2 балла)
#
# Вопрос, поставленный в прошлом задании, тем не менее, естественным образом подводит нас к концепции **иерархического временного ряда** (когда один ряд состоит из других в качестве компонент). Это полезная концепция, которая может встретиться во многих задачах. В этом задании вам предстоит самостоятельно разобраться в деталях ее реализации в ETNA с использованием справочных материалов, предоставляемых библиотекой (как это часто бывает на практике). Они содержатся по следующей ссылке:
#
# https://github.com/etna-team/etna/blob/master/examples/303-hierarchical_pipeline.ipynb
#
# На выходе из первой части задания необходимо получить `TSDataset` с иерархической структурой, а также соответствующий реконсилятор, который позволит собирать искомый ряд из составных компонент. Классы, которые вам понадобятся, импортированы ниже.

# %%
from etna.datasets import HierarchicalStructure
from etna.pipeline import HierarchicalPipeline
from etna.reconciliation import TopDownReconciliator

# %%
#YOUR CODE HERE#

# %% [markdown]
# Во второй части задания примените найденные на предыдущих этапах преобразования очистку от выбросов уже к иерархическому датасету, и запустите на нем Prophet с MAE на кросс-валидации.

# %%
#YOUR CODE HERE#

# %% [markdown]
# ### Задание 5. Построение признаков (1.5 балла)
#
# Вернемся к нашему исходному мультисегментному ряду - теперь поработаем с моделями, которые требуют построения признаков - `ARIMA` и `CatBoost`. Построим для них признаки, и попробуем при помощи них добиться улучшения качества.
#
# Из обязательного:
# 1) постройте графики автокорреляции и при помощи них обоснуйте выбор лаговых признаков
# 2) для катбуста включите в признаки результаты STL разложения. STL используем для убирания тренда за счет преобразования на месте.
# * Кроме этого, подумайте на экспертном уровне,
#     - Какие еще закономерности могут присутствовать и почему?
#     - Что из этого кажется более предсказуемым, и почему?
#     - Cделайте соответствующие признаки, и снабдите их кратким комментарием.
#
# 3) После этого, обучите на получившихся признаках модели. Для `CatBoost` рассмотрите 2 версии мультисегментную и на каждый ряд в отдельности.
#
# Ниже приведены импорты, которые вам точно понадобятся - к ним необходимо добавить те инструменты, которые вы дополнительно решите использовать в анализе.

# %%
from etna.analysis import acf_plot, stl_plot
from etna.ensembles import DirectEnsemble, StackingEnsemble, VotingEnsemble
from etna.models import (CatBoostMultiSegmentModel, CatBoostPerSegmentModel,
                         AutoARIMAModel)
from etna.transforms import STLTransform, LagTransform, SegmentEncoderTransform

# %%
from etna.analysis import plot_forecast
train_ts, test_ts = ts.train_test_split(
    train_start="2019-01-01",
    train_end="2019-10-31",
    test_start="2019-11-01",
    test_end="2019-11-30",
)

model = Pipeline(
    model=CatBoostMultiSegmentModel(),
    transforms=transforms,
    horizon=HORIZON,
)

model.fit(train_ts)
forecast_ts = model.forecast()

smape = SMAPE()
smape(y_true=test_ts, y_pred=forecast_ts)

# %% [markdown]
# ### Задание 6. Стратегии прогнозирования (1.25 балла)
#
# Как нам известно по семинарским занятиям, при построении прогноза на горизонте дальше следующего наблюдения перед нами встает задача определиться со стратегией генерации прогноза. Попробуйте разные стратегии на нашем горизонте из 5 дней (прямая, рекурсивная). Какая стратегия в совокупности с какой моделью дает лучший результат?
#
# Учитывайте особенности, которые некоторые стратегии могут накладывать на признаки (в частности, на лаговые переменные).
#
# При необходимости, в смешанном методе пользуйтесь упрощенной схемой спецификации моделей/преобразований.

# %%
from etna.pipeline import AutoRegressivePipeline, Pipeline, assemble_pipelines
from etna.ensembles import DirectEnsemble

# %%
#YOUR CODE HERE#

# %% [markdown]
# ### Задание 7. Ансамбли (1.25 балла)
#
# Чтобы не выбирать лучшую модель, мы можем использовать преимущества каждой - давайте объединим все наши наработки в ансамбль. Попробуйте различные опции ансамблирования, и выберите ту, которая работает лучше всего (не забывайте, что внутри каждого ансамбля у нас тоже есть параметры, которые мы можем варьировать - веса в voting, включаемые признаки в stacking).

# %%
from etna.ensembles import StackingEnsemble, VotingEnsemble

# %%
#YOUR CODE HERE#

# %% [markdown]
# ### Задание 8*. Трансформер (бонус 2 балла)
#
# Для желающих протестировать мощь трансформенных моделей предлагается "завести" модель из второго семинара по временным рядам на текущем датасете. На этот раз абсолютно все необходимые импорты и зависимости подгружаются на ваше усмотрение. Удалось ли вам улучшить качество по сравнению с классическими моделями / моделями на основе ML? Что бы вы предпочли внедрить в production?

# %% [markdown]
# *NB:* все, конечно, прекрасно знают механизм работы бонусных заданий, но порядка ряди прописать дисклеймер должны - итоговый балл за домашнее задание ставится по формуле min(10, ваш суммарный балл за задания).

# %%
#YOUR CODE HERE#
